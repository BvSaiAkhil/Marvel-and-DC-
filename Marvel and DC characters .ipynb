# %%
import os

# %%
os.chdir('/home/akhilbvs/VIDYA/Machine Learning A-Z /Kaggle/fivethirtyeight-comic-characters-dataset')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.offline as py
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools 
import plotly.figure_factory as ff

# %%
marvel=pd.read_csv('marvel-wikia-data.csv')
dc=pd.read_csv('dc-wikia-data.csv')

# %%
marvel.head()
# Out:
#    page_id                                 name  \
# 0     1678            Spider-Man (Peter Parker)
# 1     7139      Captain America (Steven Rogers)
# 2    64786  Wolverine (James \"Logan\" Howlett)
# 3     1868    Iron Man (Anthony \"Tony\" Stark)
# 4     2460                  Thor (Thor Odinson)
#
#                                    urlslug                ID  \
# 0              \/Spider-Man_(Peter_Parker)   Secret Identity
# 1        \/Captain_America_(Steven_Rogers)   Public Identity
# 2  \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3    \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                    \/Thor_(Thor_Odinson)  No Dual Identity
#
#                 ALIGN         EYE        HAIR              SEX  GSM  \
# 0     Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1     Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2  Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# ...

# %%
dc.head()
# Out:
#    page_id                         name                              urlslug  \
# 0     1422         Batman (Bruce Wayne)         \/wiki\/Batman_(Bruce_Wayne)
# 1    23387        Superman (Clark Kent)        \/wiki\/Superman_(Clark_Kent)
# 2     1458   Green Lantern (Hal Jordan)   \/wiki\/Green_Lantern_(Hal_Jordan)
# 3     1659     James Gordon (New Earth)     \/wiki\/James_Gordon_(New_Earth)
# 4     1576  Richard Grayson (New Earth)  \/wiki\/Richard_Grayson_(New_Earth)
#
#                 ID            ALIGN         EYE        HAIR              SEX  \
# 0  Secret Identity  Good Characters   Blue Eyes  Black Hair  Male Characters
# 1  Secret Identity  Good Characters   Blue Eyes  Black Hair  Male Characters
# 2  Secret Identity  Good Characters  Brown Eyes  Brown Hair  Male Characters
# 3  Public Identity  Good Characters  Brown Eyes  White Hair  Male Characters
# 4  Secret Identity  Good Characters   Blue Eyes  Black Hair  Male Characters
#
# ...

# %%
marvel_sex_count=marvel['SEX'].value_counts()
dc_sex_counts=dc['SEX'].value_counts()

# %%
plt.figure(figsize=(15,5))
plt.bar(x=marvel_sex_count.index,height=marvel_sex_count.values,color='red')
plt.title('Marvel Gender comparision')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.bar(x=dc_sex_counts.index,height=dc_sex_counts.values,color='blue')
plt.title('DC Gender Comparision')
plt.show()

# %%
marvel_indentity=marvel['ID'].value_counts()
dc_identity=dc['ID'].value_counts()

# %%
plt.figure(1,figsize=(15,5))
plt.bar(x=marvel_indentity.index,height=marvel_indentity.values,color='red')
plt.title('Marvel Identity comparision')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.bar(x=dc_identity.index,height=dc_identity.values,color='blue')
plt.title('DC Identity Comparision')
plt.show()

# %%
marvel_align=marvel['ALIGN'].value_counts()
dc_align=dc['ALIGN'].value_counts()

# %%
plt.figure(1,figsize=(15,5))
plt.bar(x=marvel_align.index,height=marvel_align.values,color='red')
plt.title('Marvel Alignment comparision')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.bar(dc_align.index,height=dc_align.values,color='blue')
plt.title('DC Alignment Comparision')
plt.show()

# %%
marvel_alive=marvel['ALIVE'].value_counts()
dc_alive=dc['ALIVE'].value_counts()

# %%
plt.figure(1,figsize=(15,5))
plt.bar(x=marvel_alive.index,height=marvel_alive.values,color='red')
plt.title('Marvel Characters alive or dead')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.bar(x=dc_alive.index,height=dc_alive.values,color='blue')
plt.title('DC characters alive or dead')
plt.show()

# %%
marvel_top10=marvel.sort_values(by='APPEARANCES',ascending=False).head(10)

# %%
plt.figure(figsize=(25,10))
plt.bar(x=marvel_top10['name'],height=marvel_top10['APPEARANCES'],color='red')
plt.xticks(rotation=90)
plt.show()

# %%
dc_top10=dc.sort_values(by='APPEARANCES',ascending=False).head(10)

# %%
plt.figure(figsize=(25,10))
plt.bar(x=dc_top10['name'],height=dc_top10['APPEARANCES'],color='blue')
plt.xticks(rotation=90)
plt.show()

# %%
marvel_bad=marvel[marvel['ALIGN']=='Bad Characters']

# %%
marvel_bad10=marvel_bad.sort_values(by='APPEARANCES',ascending=False).head(10)

# %%
plt.figure(figsize=(25,10))
plt.bar(x=marvel_bad10['name'],height=marvel_bad10['APPEARANCES'],color='red')
plt.xticks(rotation=90)
plt.show()

# %%
dc_bad=dc[dc['ALIGN']=='Bad Characters']

# %%
dc_bad10=dc_bad.sort_values(by='APPEARANCES',ascending=False).head(10)

# %%
plt.figure(figsize=(25,10))
plt.bar(x=dc_bad10['name'],height=dc_bad10['APPEARANCES'],color='blue')
plt.xticks(rotation=90)
plt.show()

# %%
marvel_eye=marvel['EYE'].value_counts()
dc_eye=dc['EYE'].value_counts()

# %%
plt.figure(figsize=(15,5))
plt.bar(x=marvel_eye.index,height=marvel_eye.values,color='red')
plt.xticks(rotation=90)
plt.title('Marvel Eye Comparision')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.bar(x=dc_eye.index,height=dc_eye.values,color='blue')
plt.title('DC Eye Comparision')
plt.xticks(rotation=90)
plt.show()
